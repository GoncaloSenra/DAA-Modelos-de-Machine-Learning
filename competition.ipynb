# %% [markdown]
# # Produção Energética e Sustentabilidade

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
energia2022 = pd.read_csv('daasbstp2023/train/energia_202201-202212.csv', encoding='latin-1')    
energia2021 = pd.read_csv('daasbstp2023/train/energia_202109-202112.csv', encoding='latin-1')

meteo2022 = pd.read_csv('daasbstp2023/train/meteo_202201-202212.csv', encoding='latin-1')
meteo2021 = pd.read_csv('daasbstp2023/train/meteo_202109-202112.csv', encoding='latin-1')

# %%
energia2021.head()
# Out:
#          Data  Hora  Normal (kWh)  Horário Económico (kWh)  Autoconsumo (kWh)  \
# 0  2021-09-29     0           0.0                      0.0                0.0
# 1  2021-09-29     1           0.0                      0.0                0.0
# 2  2021-09-29     2           0.0                      0.0                0.0
# 3  2021-09-29     3           0.0                      0.0                0.0
# 4  2021-09-29     4           0.0                      0.0                0.0
#
#   Injeção na rede (kWh)
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
energia2022.head()
# Out:
#          Data  Hora  Normal (kWh)  Horário Económico (kWh)  Autoconsumo (kWh)  \
# 0  2022-01-01     0           0.0                    0.486                0.0
# 1  2022-01-01     1           0.0                    0.429                0.0
# 2  2022-01-01     2           0.0                    0.463                0.0
# 3  2022-01-01     3           0.0                    0.545                0.0
# 4  2022-01-01     4           0.0                    0.439                0.0
#
#   Injeção na rede (kWh)
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
meteo2021.head()
# Out:
#            dt                         dt_iso city_name   temp  feels_like  \
# 0  1630454400  2021-09-01 00:00:00 +0000 UTC     local  18.74       18.84
# 1  1630458000  2021-09-01 01:00:00 +0000 UTC     local  18.73       18.83
# 2  1630461600  2021-09-01 02:00:00 +0000 UTC     local  17.84       17.98
# 3  1630465200  2021-09-01 03:00:00 +0000 UTC     local  18.27       18.40
# 4  1630468800  2021-09-01 04:00:00 +0000 UTC     local  17.81       17.97
#
#    temp_min  temp_max  pressure  sea_level  grnd_level  humidity  wind_speed  \
# 0     15.72     20.34      1015        NaN         NaN        83        1.18
# 1     15.72     20.34      1014        NaN         NaN        83        1.46
# 2     16.72     20.34      1014        NaN         NaN        88        1.05
# 3     16.68     20.34      1014        NaN         NaN        86        0.46
# 4     16.12     20.34      1013        NaN         NaN        89        0.93
#
#    rain_1h  clouds_all weather_description
# 0      NaN          78       broken clouds
# 1      NaN          92     overcast clouds
# 2      NaN          91     overcast clouds
# 3     0.14          94          light rain
# 4     1.26          95       moderate rain

# %%
meteo2022.head()
# Out:
#            dt                         dt_iso city_name   temp  feels_like  \
# 0  1640995200  2022-01-01 00:00:00 +0000 UTC     local  16.59       16.00
# 1  1640998800  2022-01-01 01:00:00 +0000 UTC     local  16.59       16.00
# 2  1641002400  2022-01-01 02:00:00 +0000 UTC     local  16.59       16.03
# 3  1641006000  2022-01-01 03:00:00 +0000 UTC     local  13.59       12.75
# 4  1641009600  2022-01-01 04:00:00 +0000 UTC     local  14.97       14.27
#
#    temp_min  temp_max  pressure  sea_level  grnd_level  humidity  wind_speed  \
# 0     16.21     16.72      1024        NaN         NaN        65        3.15
# 1     16.21     16.72      1024        NaN         NaN        65        3.14
# 2     15.67     16.72      1024        NaN         NaN        66        3.12
# 3     11.61     16.16      1023        NaN         NaN        67        3.08
# 4     14.72     15.66      1023        NaN         NaN        67        3.12
#
#    rain_1h  clouds_all weather_description
# 0      NaN          97     overcast clouds
# 1      NaN          58       broken clouds
# 2      NaN          23          few clouds
# 3      NaN          22          few clouds
# 4      NaN          15          few clouds

# %%
energia2021.info()
print('')
energia2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2256 entries, 0 to 2255
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Data                     2256 non-null   object
#  1   Hora                     2256 non-null   int64
#  2   Normal (kWh)             2256 non-null   float64
#  3   Horário Económico (kWh)  2256 non-null   float64
#  4   Autoconsumo (kWh)        2256 non-null   float64
#  5   Injeção na rede (kWh)    566 non-null    object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 105.9+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Data                     8760 non-null   object
#  1   Hora                     8760 non-null   int64
#  2   Normal (kWh)             8760 non-null   float64
#  3   Horário Económico (kWh)  8760 non-null   float64
#  4   Autoconsumo (kWh)        8760 non-null   float64
#  5   Injeção na rede (kWh)    2673 non-null   object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 410.8+ KB

# %%
meteo2021.info()
print('')
meteo2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2928 entries, 0 to 2927
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dt                   2928 non-null   int64
#  1   dt_iso               2928 non-null   object
#  2   city_name            2928 non-null   object
#  3   temp                 2928 non-null   float64
#  4   feels_like           2928 non-null   float64
#  5   temp_min             2928 non-null   float64
#  6   temp_max             2928 non-null   float64
#  7   pressure             2928 non-null   int64
#  8   sea_level            0 non-null      float64
#  9   grnd_level           0 non-null      float64
#  10  humidity             2928 non-null   int64
#  11  wind_speed           2928 non-null   float64
#  12  rain_1h              537 non-null    float64
#  13  clouds_all           2928 non-null   int64
#  14  weather_description  2928 non-null   object
# dtypes: float64(8), int64(4), object(3)
# memory usage: 343.2+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dt                   8760 non-null   int64
#  1   dt_iso               8760 non-null   object
#  2   city_name            8760 non-null   object
#  3   temp                 8760 non-null   float64
#  4   feels_like           8760 non-null   float64
#  5   temp_min             8760 non-null   float64
#  6   temp_max             8760 non-null   float64
#  7   pressure             8760 non-null   int64
#  8   sea_level            0 non-null      float64
#  9   grnd_level           0 non-null      float64
#  10  humidity             8760 non-null   int64
#  11  wind_speed           8760 non-null   float64
#  12  rain_1h              1898 non-null   float64
#  13  clouds_all           8760 non-null   int64
#  14  weather_description  8760 non-null   object
# dtypes: float64(8), int64(4), object(3)
# memory usage: 1.0+ MB

# %%
energia2021.describe()
# Out:
#               Hora  Normal (kWh)  Horário Económico (kWh)  Autoconsumo (kWh)
# count  2256.000000   2256.000000              2256.000000        2256.000000
# mean     11.500000      0.305831                 0.123770           0.103501
# std       6.923721      0.374957                 0.310305           0.169716
# min       0.000000      0.000000                 0.000000           0.000000
# 25%       5.750000      0.000000                 0.000000           0.000000
# 50%      11.500000      0.242000                 0.000000           0.000000
# 75%      17.250000      0.459000                 0.000000           0.213250
# max      23.000000      2.540000                 6.978000           1.016000

# %%
energia2022.describe()
# Out:
#               Hora  Normal (kWh)  Horário Económico (kWh)  Autoconsumo (kWh)
# count  8760.000000   8760.000000              8760.000000        8760.000000
# mean     11.500000      0.175610                 0.168971           0.120871
# std       6.922582      0.337526                 0.260172           0.178368
# min       0.000000      0.000000                 0.000000           0.000000
# 25%       5.750000      0.000000                 0.000000           0.000000
# 50%      11.500000      0.000000                 0.000000           0.001000
# 75%      17.250000      0.239000                 0.301000           0.229000
# max      23.000000      3.251000                 2.667000           1.192000

# %%
meteo2021.describe()
# Out:
#                  dt         temp   feels_like     temp_min     temp_max  \
# count  2.928000e+03  2928.000000  2928.000000  2928.000000  2928.000000
# mean   1.635723e+09    15.571301    15.165546    14.008275    16.367978
# std    3.043386e+06     4.794614     5.223424     4.678427     4.835628
# min    1.630454e+09     2.590000     1.290000    -0.640000     4.040000
# 25%    1.633089e+09    11.887500    11.477500    10.660000    12.857500
# 50%    1.635723e+09    15.470000    15.125000    13.945000    15.720000
# 75%    1.638357e+09    18.932500    18.852500    17.320000    19.560000
# max    1.640992e+09    33.370000    32.790000    27.890000    35.340000
#
#           pressure  sea_level  grnd_level     humidity   wind_speed  \
# count  2928.000000        0.0         0.0  2928.000000  2928.000000
# mean   1019.203893        NaN         NaN    78.455943     2.591936
# std       5.241333        NaN         NaN    14.207337     1.315286
# min     997.000000        NaN         NaN    27.000000     0.090000
# 25%    1016.000000        NaN         NaN    69.000000     1.687500
# 50%    1020.000000        NaN         NaN    82.000000     2.330000
# 75%    1023.000000        NaN         NaN    91.000000     3.332500
# max    1031.000000        NaN         NaN    98.000000    11.100000
#
#           rain_1h   clouds_all
# count  537.000000  2928.000000
# mean     0.846890    53.703552
# std      1.069043    40.501986
# min      0.100000     0.000000
# 25%      0.210000     7.000000
# 50%      0.450000    59.000000
# 75%      1.000000    97.000000
# max      7.450000   100.000000

# %%
meteo2022.describe()
# Out:
#                  dt         temp   feels_like     temp_min     temp_max  \
# count  8.760000e+03  8760.000000  8760.000000  8760.000000  8760.000000
# mean   1.656761e+09    16.685846    16.380535    14.575434    17.882364
# std    9.104179e+06     5.966659     6.488003     5.043664     6.439043
# min    1.640995e+09     0.320000    -2.190000    -0.590000     1.330000
# 25%    1.648878e+09    12.400000    11.870000    11.120000    13.292500
# 50%    1.656761e+09    16.130000    15.800000    14.720000    16.820000
# 75%    1.664644e+09    19.930000    19.895000    17.720000    21.365000
# max    1.672528e+09    40.850000    41.330000    36.720000    41.450000
#
#           pressure  sea_level  grnd_level     humidity   wind_speed  \
# count  8760.000000        0.0         0.0  8760.000000  8760.000000
# mean   1018.003311        NaN         NaN    76.005023     2.666323
# std       6.345541        NaN         NaN    16.714502     1.503035
# min     994.000000        NaN         NaN    19.000000     0.060000
# 25%    1014.000000        NaN         NaN    65.000000     1.580000
# 50%    1018.000000        NaN         NaN    80.000000     2.400000
# 75%    1022.000000        NaN         NaN    90.000000     3.420000
# max    1034.000000        NaN         NaN   100.000000    10.230000
#
#            rain_1h   clouds_all
# count  1898.000000  8760.000000
# mean      0.895474    54.443607
# std       1.074736    40.424382
# min       0.100000     0.000000
# 25%       0.210000     7.000000
# 50%       0.450000    61.000000
# 75%       1.117500    98.000000
# max       6.750000   100.000000

# %%
energia2021.isnull().sum()
# Out:
# Data                          0
# Hora                          0
# Normal (kWh)                  0
# Horário Económico (kWh)       0
# Autoconsumo (kWh)             0
# Injeção na rede (kWh)      1690
# dtype: int64

# %%
energia2022.isnull().sum()
# Out:
# Data                          0
# Hora                          0
# Normal (kWh)                  0
# Horário Económico (kWh)       0
# Autoconsumo (kWh)             0
# Injeção na rede (kWh)      6087
# dtype: int64

# %%
meteo2021.isnull().sum()
# Out:
# dt                        0
# dt_iso                    0
# city_name                 0
# temp                      0
# feels_like                0
# temp_min                  0
# temp_max                  0
# pressure                  0
# sea_level              2928
# grnd_level             2928
# humidity                  0
# wind_speed                0
# rain_1h                2391
# clouds_all                0
# weather_description       0
# dtype: int64

# %%
meteo2022.isnull().sum()
# Out:
# dt                        0
# dt_iso                    0
# city_name                 0
# temp                      0
# feels_like                0
# temp_min                  0
# temp_max                  0
# pressure                  0
# sea_level              8760
# grnd_level             8760
# humidity                  0
# wind_speed                0
# rain_1h                6862
# clouds_all                0
# weather_description       0
# dtype: int64

# %%
data21 = pd.concat([energia2021, meteo2021], axis=1)
data22 = pd.concat([energia2022, meteo2022], axis=1)

# %%
data21.head()
# Out:
#          Data  Hora  Normal (kWh)  Horário Económico (kWh)  Autoconsumo (kWh)  \
# 0  2021-09-29   0.0           0.0                      0.0                0.0
# 1  2021-09-29   1.0           0.0                      0.0                0.0
# 2  2021-09-29   2.0           0.0                      0.0                0.0
# 3  2021-09-29   3.0           0.0                      0.0                0.0
# 4  2021-09-29   4.0           0.0                      0.0                0.0
#
#   Injeção na rede (kWh)          dt                         dt_iso city_name  \
# 0                   NaN  1630454400  2021-09-01 00:00:00 +0000 UTC     local
# 1                   NaN  1630458000  2021-09-01 01:00:00 +0000 UTC     local
# 2                   NaN  1630461600  2021-09-01 02:00:00 +0000 UTC     local
# 3                   NaN  1630465200  2021-09-01 03:00:00 +0000 UTC     local
# 4                   NaN  1630468800  2021-09-01 04:00:00 +0000 UTC     local
#
#     temp  ...  temp_min  temp_max  pressure  sea_level  grnd_level  humidity  \
# 0  18.74  ...     15.72     20.34      1015        NaN         NaN        83
# 1  18.73  ...     15.72     20.34      1014        NaN         NaN        83
# 2  17.84  ...     16.72     20.34      1014        NaN         NaN        88
# 3  18.27  ...     16.68     20.34      1014        NaN         NaN        86
# 4  17.81  ...     16.12     20.34      1013        NaN         NaN        89
#
#    wind_speed  rain_1h  clouds_all  weather_description
# 0        1.18      NaN          78        broken clouds
# 1        1.46      NaN          92      overcast clouds
# 2        1.05      NaN          91      overcast clouds
# 3        0.46     0.14          94           light rain
# 4        0.93     1.26          95        moderate rain
#
# [5 rows x 21 columns]

# %%
data22.head()
# Out:
#          Data  Hora  Normal (kWh)  Horário Económico (kWh)  Autoconsumo (kWh)  \
# 0  2022-01-01     0           0.0                    0.486                0.0
# 1  2022-01-01     1           0.0                    0.429                0.0
# 2  2022-01-01     2           0.0                    0.463                0.0
# 3  2022-01-01     3           0.0                    0.545                0.0
# 4  2022-01-01     4           0.0                    0.439                0.0
#
#   Injeção na rede (kWh)          dt                         dt_iso city_name  \
# 0                   NaN  1640995200  2022-01-01 00:00:00 +0000 UTC     local
# 1                   NaN  1640998800  2022-01-01 01:00:00 +0000 UTC     local
# 2                   NaN  1641002400  2022-01-01 02:00:00 +0000 UTC     local
# 3                   NaN  1641006000  2022-01-01 03:00:00 +0000 UTC     local
# 4                   NaN  1641009600  2022-01-01 04:00:00 +0000 UTC     local
#
#     temp  ...  temp_min  temp_max  pressure  sea_level  grnd_level  humidity  \
# 0  16.59  ...     16.21     16.72      1024        NaN         NaN        65
# 1  16.59  ...     16.21     16.72      1024        NaN         NaN        65
# 2  16.59  ...     15.67     16.72      1024        NaN         NaN        66
# 3  13.59  ...     11.61     16.16      1023        NaN         NaN        67
# 4  14.97  ...     14.72     15.66      1023        NaN         NaN        67
#
#    wind_speed  rain_1h  clouds_all  weather_description
# 0        3.15      NaN          97      overcast clouds
# 1        3.14      NaN          58        broken clouds
# 2        3.12      NaN          23           few clouds
# 3        3.08      NaN          22           few clouds
# 4        3.12      NaN          15           few clouds
#
# [5 rows x 21 columns]

# %%
data21.info()
print('')
data22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2928 entries, 0 to 2927
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Data                     2256 non-null   object
#  1   Hora                     2256 non-null   float64
#  2   Normal (kWh)             2256 non-null   float64
#  3   Horário Económico (kWh)  2256 non-null   float64
#  4   Autoconsumo (kWh)        2256 non-null   float64
#  5   Injeção na rede (kWh)    566 non-null    object
#  6   dt                       2928 non-null   int64
#  7   dt_iso                   2928 non-null   object
#  8   city_name                2928 non-null   object
#  9   temp                     2928 non-null   float64
#  10  feels_like               2928 non-null   float64
#  11  temp_min                 2928 non-null   float64
#  12  temp_max                 2928 non-null   float64
#  13  pressure                 2928 non-null   int64
#  14  sea_level                0 non-null      float64
#  15  grnd_level               0 non-null      float64
#  16  humidity                 2928 non-null   int64
#  17  wind_speed               2928 non-null   float64
#  18  rain_1h                  537 non-null    float64
#  19  clouds_all               2928 non-null   int64
#  20  weather_description      2928 non-null   object
# dtypes: float64(12), int64(4), object(5)
# memory usage: 480.5+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Data                     8760 non-null   object
#  1   Hora                     8760 non-null   int64
#  2   Normal (kWh)             8760 non-null   float64
#  3   Horário Económico (kWh)  8760 non-null   float64
#  4   Autoconsumo (kWh)        8760 non-null   float64
#  5   Injeção na rede (kWh)    2673 non-null   object
#  6   dt                       8760 non-null   int64
#  7   dt_iso                   8760 non-null   object
#  8   city_name                8760 non-null   object
#  9   temp                     8760 non-null   float64
#  10  feels_like               8760 non-null   float64
#  11  temp_min                 8760 non-null   float64
#  12  temp_max                 8760 non-null   float64
#  13  pressure                 8760 non-null   int64
#  14  sea_level                0 non-null      float64
#  15  grnd_level               0 non-null      float64
#  16  humidity                 8760 non-null   int64
#  17  wind_speed               8760 non-null   float64
#  18  rain_1h                  1898 non-null   float64
#  19  clouds_all               8760 non-null   int64
#  20  weather_description      8760 non-null   object
# dtypes: float64(11), int64(5), object(5)
# memory usage: 1.4+ MB

# %%
data21.describe()
# Out:
#               Hora  Normal (kWh)  Horário Económico (kWh)  Autoconsumo (kWh)  \
# count  2256.000000   2256.000000              2256.000000        2256.000000
# mean     11.500000      0.305831                 0.123770           0.103501
# std       6.923721      0.374957                 0.310305           0.169716
# min       0.000000      0.000000                 0.000000           0.000000
# 25%       5.750000      0.000000                 0.000000           0.000000
# 50%      11.500000      0.242000                 0.000000           0.000000
# 75%      17.250000      0.459000                 0.000000           0.213250
# max      23.000000      2.540000                 6.978000           1.016000
#
#                  dt         temp   feels_like     temp_min     temp_max  \
# count  2.928000e+03  2928.000000  2928.000000  2928.000000  2928.000000
# mean   1.635723e+09    15.571301    15.165546    14.008275    16.367978
# std    3.043386e+06     4.794614     5.223424     4.678427     4.835628
# min    1.630454e+09     2.590000     1.290000    -0.640000     4.040000
# 25%    1.633089e+09    11.887500    11.477500    10.660000    12.857500
# 50%    1.635723e+09    15.470000    15.125000    13.945000    15.720000
# 75%    1.638357e+09    18.932500    18.852500    17.320000    19.560000
# max    1.640992e+09    33.370000    32.790000    27.890000    35.340000
#
#           pressure  sea_level  grnd_level     humidity   wind_speed  \
# count  2928.000000        0.0         0.0  2928.000000  2928.000000
# mean   1019.203893        NaN         NaN    78.455943     2.591936
# std       5.241333        NaN         NaN    14.207337     1.315286
# min     997.000000        NaN         NaN    27.000000     0.090000
# 25%    1016.000000        NaN         NaN    69.000000     1.687500
# 50%    1020.000000        NaN         NaN    82.000000     2.330000
# 75%    1023.000000        NaN         NaN    91.000000     3.332500
# max    1031.000000        NaN         NaN    98.000000    11.100000
#
#           rain_1h   clouds_all
# count  537.000000  2928.000000
# mean     0.846890    53.703552
# std      1.069043    40.501986
# min      0.100000     0.000000
# 25%      0.210000     7.000000
# 50%      0.450000    59.000000
# 75%      1.000000    97.000000
# max      7.450000   100.000000

# %%
data22.describe()
# Out:
#               Hora  Normal (kWh)  Horário Económico (kWh)  Autoconsumo (kWh)  \
# count  8760.000000   8760.000000              8760.000000        8760.000000
# mean     11.500000      0.175610                 0.168971           0.120871
# std       6.922582      0.337526                 0.260172           0.178368
# min       0.000000      0.000000                 0.000000           0.000000
# 25%       5.750000      0.000000                 0.000000           0.000000
# 50%      11.500000      0.000000                 0.000000           0.001000
# 75%      17.250000      0.239000                 0.301000           0.229000
# max      23.000000      3.251000                 2.667000           1.192000
#
#                  dt         temp   feels_like     temp_min     temp_max  \
# count  8.760000e+03  8760.000000  8760.000000  8760.000000  8760.000000
# mean   1.656761e+09    16.685846    16.380535    14.575434    17.882364
# std    9.104179e+06     5.966659     6.488003     5.043664     6.439043
# min    1.640995e+09     0.320000    -2.190000    -0.590000     1.330000
# 25%    1.648878e+09    12.400000    11.870000    11.120000    13.292500
# 50%    1.656761e+09    16.130000    15.800000    14.720000    16.820000
# 75%    1.664644e+09    19.930000    19.895000    17.720000    21.365000
# max    1.672528e+09    40.850000    41.330000    36.720000    41.450000
#
#           pressure  sea_level  grnd_level     humidity   wind_speed  \
# count  8760.000000        0.0         0.0  8760.000000  8760.000000
# mean   1018.003311        NaN         NaN    76.005023     2.666323
# std       6.345541        NaN         NaN    16.714502     1.503035
# min     994.000000        NaN         NaN    19.000000     0.060000
# 25%    1014.000000        NaN         NaN    65.000000     1.580000
# 50%    1018.000000        NaN         NaN    80.000000     2.400000
# 75%    1022.000000        NaN         NaN    90.000000     3.420000
# max    1034.000000        NaN         NaN   100.000000    10.230000
#
#            rain_1h   clouds_all
# count  1898.000000  8760.000000
# mean      0.895474    54.443607
# std       1.074736    40.424382
# min       0.100000     0.000000
# 25%       0.210000     7.000000
# 50%       0.450000    61.000000
# 75%       1.117500    98.000000
# max       6.750000   100.000000

# %%
data21.isnull().sum()
# Out:
# Data                        672
# Hora                        672
# Normal (kWh)                672
# Horário Económico (kWh)     672
# Autoconsumo (kWh)           672
# Injeção na rede (kWh)      2362
# dt                            0
# dt_iso                        0
# city_name                     0
# temp                          0
# feels_like                    0
# temp_min                      0
# temp_max                      0
# pressure                      0
# sea_level                  2928
# grnd_level                 2928
# humidity                      0
# wind_speed                    0
# rain_1h                    2391
# clouds_all                    0
# weather_description           0
# dtype: int64

# %%
sns.heatmap(data21.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
data22.isnull().sum()
# Out:
# Data                          0
# Hora                          0
# Normal (kWh)                  0
# Horário Económico (kWh)       0
# Autoconsumo (kWh)             0
# Injeção na rede (kWh)      6087
# dt                            0
# dt_iso                        0
# city_name                     0
# temp                          0
# feels_like                    0
# temp_min                      0
# temp_max                      0
# pressure                      0
# sea_level                  8760
# grnd_level                 8760
# humidity                      0
# wind_speed                    0
# rain_1h                    6862
# clouds_all                    0
# weather_description           0
# dtype: int64

# %%
sns.heatmap(data22.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
data21.drop('sea_level', axis=1, inplace=True)
data21.drop('grnd_level', axis=1, inplace=True)
data21.drop('rain_1h', axis=1, inplace=True)

#TODO: dropar linhas?

data21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2928 entries, 0 to 2927
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Data                     2256 non-null   object
#  1   Hora                     2256 non-null   float64
#  2   Normal (kWh)             2256 non-null   float64
#  3   Horário Económico (kWh)  2256 non-null   float64
#  4   Autoconsumo (kWh)        2256 non-null   float64
#  5   Injeção na rede (kWh)    566 non-null    object
#  6   dt                       2928 non-null   int64
#  7   dt_iso                   2928 non-null   object
#  8   city_name                2928 non-null   object
#  9   temp                     2928 non-null   float64
#  10  feels_like               2928 non-null   float64
#  11  temp_min                 2928 non-null   float64
#  12  temp_max                 2928 non-null   float64
#  13  pressure                 2928 non-null   int64
#  14  humidity                 2928 non-null   int64
#  15  wind_speed               2928 non-null   float64
#  16  clouds_all               2928 non-null   int64
#  17  weather_description      2928 non-null   object
# dtypes: float64(9), int64(4), object(5)
# memory usage: 411.9+ KB

# %%
sns.heatmap(data21.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
data22.drop('sea_level', axis=1, inplace=True)
data22.drop('grnd_level', axis=1, inplace=True)
data22.drop('rain_1h', axis=1, inplace=True)

data22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Data                     8760 non-null   object
#  1   Hora                     8760 non-null   int64
#  2   Normal (kWh)             8760 non-null   float64
#  3   Horário Económico (kWh)  8760 non-null   float64
#  4   Autoconsumo (kWh)        8760 non-null   float64
#  5   Injeção na rede (kWh)    2673 non-null   object
#  6   dt                       8760 non-null   int64
#  7   dt_iso                   8760 non-null   object
#  8   city_name                8760 non-null   object
#  9   temp                     8760 non-null   float64
#  10  feels_like               8760 non-null   float64
#  11  temp_min                 8760 non-null   float64
#  12  temp_max                 8760 non-null   float64
#  13  pressure                 8760 non-null   int64
#  14  humidity                 8760 non-null   int64
#  15  wind_speed               8760 non-null   float64
#  16  clouds_all               8760 non-null   int64
#  17  weather_description      8760 non-null   object
# dtypes: float64(8), int64(5), object(5)
# memory usage: 1.2+ MB

# %%
sns.heatmap(data22.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
data21.nunique()
# Out:
# Data                         94
# Hora                         24
# Normal (kWh)                772
# Horário Económico (kWh)     329
# Autoconsumo (kWh)           440
# Injeção na rede (kWh)         4
# dt                         2928
# dt_iso                     2928
# city_name                     1
# temp                       1279
# feels_like                 1476
# temp_min                    262
# temp_max                    256
# pressure                     35
# humidity                     70
# wind_speed                  569
# clouds_all                  101
# weather_description           8
# dtype: int64

# %%
data22.nunique()
# Out:
# Data                        365
# Hora                         24
# Normal (kWh)               1132
# Horário Económico (kWh)     789
# Autoconsumo (kWh)           712
# Injeção na rede (kWh)         4
# dt                         8760
# dt_iso                     8760
# city_name                     1
# temp                       2277
# feels_like                 2585
# temp_min                    424
# temp_max                    511
# pressure                     41
# humidity                     82
# wind_speed                  761
# clouds_all                  101
# weather_description           8
# dtype: int64

# %%
data21.drop('city_name', axis=1, inplace=True)
data22.drop('city_name', axis=1, inplace=True)

# %%
data21.nunique()
# Out:
# Data                         94
# Hora                         24
# Normal (kWh)                772
# Horário Económico (kWh)     329
# Autoconsumo (kWh)           440
# Injeção na rede (kWh)         4
# dt                         2928
# dt_iso                     2928
# temp                       1279
# feels_like                 1476
# temp_min                    262
# temp_max                    256
# pressure                     35
# humidity                     70
# wind_speed                  569
# clouds_all                  101
# weather_description           8
# dtype: int64

# %%
data22.nunique()
# Out:
# Data                        365
# Hora                         24
# Normal (kWh)               1132
# Horário Económico (kWh)     789
# Autoconsumo (kWh)           712
# Injeção na rede (kWh)         4
# dt                         8760
# dt_iso                     8760
# temp                       2277
# feels_like                 2585
# temp_min                    424
# temp_max                    511
# pressure                     41
# humidity                     82
# wind_speed                  761
# clouds_all                  101
# weather_description           8
# dtype: int64

# %%
data_energia21 = data21.drop(['Hora', 'dt', 'pressure', 'temp', 'feels_like', 'temp_min', 'temp_max', 'humidity', 'wind_speed', 'clouds_all'], axis=1)
plt.subplots(figsize=(14,10))
sns.boxplot(data=data_energia21, orient='v', palette='Set2')
# Out:
# <Axes: >

# %%
data_meteo21 = data21.drop(['Hora', 'dt', 'Normal (kWh)', 'Horário Económico (kWh)', 'Autoconsumo (kWh)', 'pressure'], axis=1)
plt.subplots(figsize=(14,10))
sns.boxplot(data=data_meteo21, orient='v', palette='Set2')
# Out:
# <Axes: >

# %%
plt.subplots(figsize=(14,10))
plt.xlabel('pressure')
sns.boxplot(data=data21['pressure'], orient='v', palette='Set2')
# Out:
# <Axes: xlabel='pressure'>

# %%
data_energia22 = data22.drop(['Hora', 'dt', 'pressure', 'temp', 'feels_like', 'temp_min', 'temp_max', 'humidity', 'wind_speed', 'clouds_all'], axis=1)
plt.subplots(figsize=(14,10))
sns.boxplot(data=data_energia22, orient='v', palette='Set2')
# Out:
# <Axes: >

# %%
data_meteo22 = data22.drop(['Hora', 'dt', 'Normal (kWh)', 'Horário Económico (kWh)', 'Autoconsumo (kWh)', 'pressure'], axis=1)
plt.subplots(figsize=(14,10))
sns.boxplot(data=data_meteo22, orient='v', palette='Set2')
# Out:
# <Axes: >

# %%
plt.subplots(figsize=(14,10))
plt.xlabel('pressure')
sns.boxplot(data=data22['pressure'], orient='v', palette='Set2')
# Out:
# <Axes: xlabel='pressure'>
